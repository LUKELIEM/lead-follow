# %% [markdown]
# # Crossing - Baseline
#
# ### **1T-10L: 1 Teams composed of 10 agents **
#
# The Crossing Game presents a more difficult problem than the Gathering game. In place of a single food pile, there are 2 food piles separated by a fixed distance or a barrier:
#
# * The smaller food pile is located closed to the agents, but has fewer food units than the number of agents.
# * The larger food pile has more food units than the number of agents but is located further away. The agents cannot see it unless they move away from the 1st food pile.
# * If there is a river, the agent suffers a -1.0 penalty for each game step in the river.
#
# <img src="images/Crossing01.png" width="600">
#
# <img src="images/Crossing-river.png" width="600">
#
# This game deals with two challenging issues that are difficult for reinforcement learning algorithms:
#
# 1. Sparce reward - the long distance an agent needs to explore with no reward to get to the 2nd food pile
# 2. Local Optima - the presence of the 1st smaller food pile which the agents can see

# %%
import os
import random
import time
import platform
import torch
import gym
import numpy as np
import pickle

# This is the Crossing game environment
from teams_env import CrossingEnv
from teams_model import *
from interface import *

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print("Python version: ", platform.python_version())
print("Pytorch version: {}".format(torch.__version__))
print("OpenAI Gym version: {}".format(gym.__version__))
# Out:
# Python version:  3.6.4
# Pytorch version: 0.4.1.post2
# OpenAI Gym version: 0.9.2

# %% [markdown]
# # Training Section

# %% [markdown]
# ## Temperature for Softmax Function
#
# We run parameter optimization on (temp, steps/episode) to study their effectiveness on inducing agents to overcome local optima and sparce reward. This effectiveness is measure by the number of agents who gather apples in the 2nd food pile instead of the 1st pile.

# %%
import gym
import sys
import pickle
from collections import deque

import torch
import torch.optim as optim
from torch.autograd import Variable
import numpy as np

# Initialize agents parameters
#   10 agents - 10 learning agents, 0 trained agent, 0 random agent
num_learners = 10
num_trained = 0
num_rdn = 0

num_statics = num_trained + num_rdn
num_agents = num_learners + num_statics  

# Initialize environment
game = "Crossing"
num_actions = 8                       # 8 actions in Gathering
experiment = '1T-10L/baseline/'       # 1 team of 10 agents; baseline 


# Initialize training parameters
warm_start = False
num_frames = 7      # environ observation consists of a list of stacked frames per agent
max_episodes = 3000

second_pile_x = 50  # x-coordinate of the 2nd food pile

# These trainer parameters works for Atari Breakout
gamma = 0.99  
lr = 1e-3

# Map and Parameter sets

"""
map_name = "food_d37"
parameters =[ 
            {'temp_start':1.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':1.0, 'river_penalty':-1.0, 'game_steps':600},    
            {'temp_start':1.25, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':1.25, 'river_penalty':-1.0, 'game_steps':600},    
            {'temp_start':1.5, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':1.5, 'river_penalty':-1.0, 'game_steps':600},
            {'temp_start':1.5, 'river_penalty':-1.0, 'game_steps':1200},
            {'temp_start':2.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':2.0, 'river_penalty':-1.0, 'game_steps':600},
            {'temp_start':2.0, 'river_penalty':-1.0, 'game_steps':1200},
            {'temp_start':4.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':4.0, 'river_penalty':-1.0, 'game_steps':600},
            {'temp_start':4.0, 'river_penalty':-1.0, 'game_steps':1200},
            {'temp_start':8.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':8.0, 'river_penalty':-1.0, 'game_steps':600},
            {'temp_start':8.0, 'river_penalty':-1.0, 'game_steps':1200}
            {'temp_start':1.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':1.25, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':2.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':4.0, 'river_penalty':-1.0, 'game_steps':300},
            ]
            
map_name = "food_d37_river_w1_d25"  # This is an even more difficult problem
parameters =[ 
            {'temp_start':1.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':1.25, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':2.0, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':4.0, 'river_penalty':-1.0, 'game_steps':300},
            ]
"""

map_name = "food_d37"   
parameters =[ 
            {'temp_start':0.8, 'river_penalty':-1.0, 'game_steps':300},
            {'temp_start':0.4, 'river_penalty':-1.0, 'game_steps':300},
            ]

temp_end = 1.0   # temp parameter is annealed from the value stored in parameters['temp_start'] to 1.0 

log_interval = 200
save_interval = 500


def save_model(file_name, ep, model, optimizer):
    """
    Save a training checkpoint whereby episode, model and optimizer parameters are saved into a dictionary 
    prior to being saved into the model file.
    
    Refer to:
    https://pytorch.org/tutorials/beginner/saving_loading_models.html
    """

    torch.save({
            'epoch': ep,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
    }, file_name) 
    
    return
        

# The main code starts here!!!


for parameter in parameters:   # Go down the list of parameter sets
    culture = {'name':'pacifist', 'laser_penalty':-1.0}

    start = time.clock()  # time the training
   
    temp_start = parameter['temp_start']
    river_penalty = parameter['river_penalty']
    max_frames = parameter['game_steps']

    # Data structure for agents
    agents = []
    actions = []
    log_probs = []
    tags = []
    rewards = []
    optimizers = []

    # Cold start
    if warm_start is False:
   
        # Initialize learner agents, then load static agents (trained followed by random)
        for i in range(num_learners):
            print("Learner agent {}".format(i))
            agents.append(Policy(num_frames, num_actions, i)) # No weights loaded for learning agent
            optimizers.append(optim.Adam(agents[i].parameters(), lr=lr))
        
            # set up optimizer - this works for Atari Breakout
            # optimizers.append(optim.RMSprop(agents[i].parameters(), lr=lr, weight_decay=0.1)) 
        
        for i in range(num_learners, num_learners+num_trained):
            print ("Learning with trained agents - not implemented yet!")
            raise
            """
            Disable for now! No need to train with trained agents.
            agents.append(Policy(num_frames, num_actions, i))
            agents[i].load_weights()         # load weight for static agent        
            """
        for i in range(num_learners+num_trained, num_agents):
            print("Load random agent {}".format(i))
            agents.append(Rdn_Policy())

    
        # Initialize all agent data
        actions = [0 for i in range(num_agents)]
        log_probs = [0 for i in range(num_agents)]
        tags = [0 for i in range(num_agents)]
        rewards = [0 for i in range(num_agents)]

        # Keep track of rewards learned by learners
        episode_reward = [0 for i in range(num_learners)]   # reward for an episode
        running_reward = [None for i in range(num_learners)]   # running average
        running_rewards = [[] for i in range(num_learners)]   # history of running averages
        best_reward = [0 for i in range(num_learners)]    # best running average (for storing best_model)
        
        # Keep track of num learners who has crossed over to the 2nd food pile
        crossed = [0 for i in range(num_learners)]      # whether an agent has crossed to the 2nd food pile  
        episode_crossed = 0                             # num learners who has crossed for an episode
        running_crossed = None         # running average
        running_crossed_hist = []   # history of running averages

        # This is to support warm start for training
        prior_eps = 0

    # Warm start
    if warm_start:
        print ("Cannot warm start")
        raise
    
        """
        # Disable for now!  Need to ensure model can support training on GPU and game playing
        # on both CPU and GPU.
    
        data_file = 'results/{}.p'.format(game)

        try:
            with open(data_file, 'rb') as f:
                running_rewards = pickle.load(f)
                running_reward = running_rewards[-1]

            prior_eps = len(running_rewards)

            model_file = 'saved_models/actor_critic_{}_ep_{}.p'.format(game, prior_eps)
            with open(model_file, 'rb') as f:
                # Model Save and Load Update: Include both model and optim parameters
                saved_model = pickle.load(f)
                model, optimizer = saved_model

        except OSError:
            print('Saved file not found. Creating new cold start model.')
            model = Policy(input_channels=num_frames, num_actions=num_actions)
            optimizer = optim.RMSprop(model.parameters(), lr=lr,
                                      weight_decay=0.1)
            running_rewards = []
            prior_eps = 0
        """

    # Establish tribal association

    tribes = []
    tribes.append(Tribe(name='Vikings',color='blue', culture=culture, \
                    agents=[agents[0], agents[1], agents[2], agents[3], agents[4], \
                           agents[5], agents[6], agents[7], agents[8], agents[9]]))
    
    # tribes.append(Tribe(name='Saxons', color='red', culture=culture, \
    #                agents=[agents[4], agents[5], agents[6], agents[7]]))
    # tribes.append(Tribe(name='Franks', color='purple', culture=culture, \
    #                agents=[agents[8], agents[9], agents[10], agents[11]]))
    # tribes.append(Tribe(name='Crazies', color='yellow', agents=[agents[9]]))   # random agents are crazy!!!


    # Set up agent and tribe info to pass into env
    agent_colors = [agent.color for agent in agents]
    agent_tribes = [agent.tribe for agent in agents]
    tribe_names = [tribe.name for tribe in tribes]
    
    env = CrossingEnv(n_agents=num_agents,agent_colors=agent_colors, agent_tribes=agent_tribes, \
                        map_name=map_name, river_penalty=river_penalty, tribes=tribe_names)    
    
    cuda = torch.cuda.is_available()

    if cuda:
        for i in range(num_learners):    # Learning agents need to utilize GPU
            agents[i].cuda()

        
    for ep in range(max_episodes):
    
        print('.', end='')  # To show progress
    
        # Anneal temperature from temp_start to temp_end
        for i in range(num_learners):    # For learning agents
            agents[i].temperature = max(temp_end, temp_start - (temp_start - temp_end) * (ep / max_episodes))

        env_obs = env.reset()  # Env return observations

        # For Debug only
        # print (len(env_obs))
        # print (env_obs[0].shape)
    
        # Unpack observations into data structure compatible with agent Policy
        agents_obs = unpack_env_obs(env_obs)

        for i in range(num_learners):    # Reset agent info - laser tag statistics
            agents[i].reset_info()   

        # For Debug only
        # print (len(agents_obs))
        # print (agents_obs[0].shape)
    
        """
        For now, we do not stack observations, and we do not implement LSTM
    
        state = np.stack([state]*num_frames)

        # LSTM change - reset LSTM hidden units when episode begins
        cx = Variable(torch.zeros(1, 256))
        hx = Variable(torch.zeros(1, 256))
        if cuda:
            cx = cx.cuda()
            hx = hx.cuda()
        """

        # Initialize reward and agents crossed counters
        episode_reward = [0 for i in range(num_learners)]   # reward for an episode
        crossed = [0 for i in range(num_learners)]      # whether an agent has crossed to the 2nd food pile  
        episode_crossed = 0                             # num learners who has crossed for an episode

    
        for frame in range(max_frames):

            """
            For now, we do not implement LSTM
            # Select action
            # LSTM Change: Need to cycle hx and cx thru select_action
            action, log_prob, value, (hx,cx)  = select_action(model, state, (hx,cx), cuda)        
            """

            for i in range(num_learners):    # For learning agents
                actions[i], log_probs[i] = select_action(agents[i], agents_obs[i], cuda)
                if actions[i] is 6:
                    tags[i] += 1   # record a tag for accessing aggressiveness
                agents[i].saved_actions.append((log_probs[i]))
            
                # Do not implement LSTM for now
                # actions[i].saved_actions.append((log_prob, value))
            
            for i in range(num_learners, num_learners+num_trained):
                print ("No trained agent exist yet!")
                raise
            for i in range(num_learners+num_trained, num_agents):   # For random agents
                actions[i] = agents[i].select_action(agents_obs[i])
                if actions[i] is 6:
                    tags[i] += 1   # record a tag for accessing aggressiveness

            # For Debug only
            # if frame % 20 == 0:
            #    print (actions) 
            #    print (log_probs)
            
            # Perform step        
            env_obs, reward, done, info = env.step(actions)
        
            """
            For Debug only
            print (env_obs)
            print (reward)
            print (done) 
            """
       
            # Unpack observations into data structure compatible with agent Policy
            agents_obs = unpack_env_obs(env_obs)
            load_info(agents, info, narrate=False)   # Load agent info for AI agents

            # For learner agents only, generate reward statistics and reward stack for policy gradient
            for i in range(num_learners):
                agents[i].rewards.append(reward[i])  # Stack rewards (for policy gradient)
                episode_reward[i] += reward[i]   # accumulate episode reward 
            
            """
            For now, we do not stack observation, may come in handy later on
        
            # Evict oldest diff add new diff to state
            next_state = np.stack([next_state]*num_frames)
            next_state[1:, :, :] = state[:-1, :, :]
            state = next_state
            """

            if any(done):
                print("Done after {} frames".format(frame))
                break

        # Keep track num of agents who gather from 2nd food pile. Note that env.consumption tracks the 
        # agent index and location of apple gathered
        for (i, loc) in env.consumption:
            if loc[0] > second_pile_x:   # If x-cood of gathered apple is beyond a preset value, it is
                                         # in the 2nd pile
                crossed[i] = 1
        episode_crossed = sum(crossed)   # sum up the num agents who crossed to 2nd pile for the episode
                
        # Update reward and crossed statistics for learners
        for i in range(num_learners):
            if running_reward[i] is None:
                running_reward[i] = episode_reward[i]
            running_reward[i] = running_reward[i] * 0.99 + episode_reward[i] * 0.01
            running_rewards[i].append(running_reward[i])
            
        if running_crossed is None:
            running_crossed = episode_crossed
        running_crossed = running_crossed * 0.99 + episode_crossed * 0.01
        running_crossed_hist.append(running_crossed)
                
        # Track Episode #, temp and highest frames/episode
        if (ep+prior_eps+1) % log_interval == 0: 
            verbose_str = '\nEpisode {} complete'.format(ep+prior_eps+1)
            # verbose_str += '\tTemp = {:.4}'.format(model.temperature)
            print(verbose_str)
    
            # Display rewards and running rewards for learning agents
            for i in range(num_learners):
                verbose_str = 'Learner:{}'.format(i)
                verbose_str += '\tReward total:{}'.format(episode_reward[i])
                verbose_str += '\tRunning mean: {:.4}'.format(running_reward[i])
                verbose_str += '\tNum agents crossed: {}'.format(episode_crossed)
                verbose_str += '\tRunning mean: {:.4}'.format(running_crossed)
                print(verbose_str)
    
        # Update model
        total_norms = finish_episode(tribes, agents[0:num_learners], optimizers[0:num_learners], gamma, cuda)

        if (ep+prior_eps+1) % log_interval == 0:
            print('Max Norms = ',["%0.2f" % i for i in total_norms])
        
        if (ep+prior_eps+1) % save_interval == 0: 
            for i in range(num_learners):
                model_dir = 'models/' + experiment + map_name
                results_dir = 'results/' + experiment + map_name

                model_file = model_dir+'/{}/t{}_rp{}_{}gs/MA{}_{}_ep{}.p'.format(culture['name'], \
                        temp_start, river_penalty, max_frames, \
                        i, game, ep+prior_eps+1)
                data_file = results_dir+'/{}/t{}_rp{}_{}gs/MA{}_{}.p'.format(culture['name'], \
                        temp_start, river_penalty, max_frames, \
                        i, game)

                os.makedirs(os.path.dirname(model_file), exist_ok=True)
                os.makedirs(os.path.dirname(data_file), exist_ok=True)
                
                with open(model_file, 'wb') as f:
                    # Model Save and Load Update: Include both model and optim parameters 
                    save_model(f, ep, agents[i], optimizers[i])

                with open(data_file, 'wb') as f:
                    pickle.dump(running_rewards[i], f)    
             
            crossed_file = results_dir+'/{}/t{}_rp{}_{}gs/Crossed.p'.format(culture['name'], \
                        temp_start, river_penalty, max_frames)
            os.makedirs(os.path.dirname(crossed_file), exist_ok=True)
            with open(crossed_file, 'wb') as f:
                    pickle.dump(running_crossed_hist, f)
    
    end = time.clock()
    print('\nTraining time: {:.2f} min'.format((end-start)/60.0))
            
    env.close()  # Close the environment
# Out:
# Learner agent 0
# Learner agent 1
# Learner agent 2
# Learner agent 3
# Learner agent 4
# Learner agent 5
# Learner agent 6
# Learner agent 7
# Learner agent 8
# Learner agent 9
# ........................................................................................................................................................................................................
# Episode 200 complete
# Learner:0	Reward total:0	Running mean: 0.7612	Num agents crossed: 0	Running mean: 0.4774
# Learner:1	Reward total:1	Running mean: 0.3269	Num agents crossed: 0	Running mean: 0.4774
# Learner:2	Reward total:1	Running mean: 0.1463	Num agents crossed: 0	Running mean: 0.4774
# Learner:3	Reward total:0	Running mean: 0.6208	Num agents crossed: 0	Running mean: 0.4774
# Learner:4	Reward total:10	Running mean: 2.001	Num agents crossed: 0	Running mean: 0.4774
# Learner:5	Reward total:0	Running mean: 0.08495	Num agents crossed: 0	Running mean: 0.4774
# Learner:6	Reward total:3	Running mean: 4.037	Num agents crossed: 0	Running mean: 0.4774
# Learner:7	Reward total:1	Running mean: 1.153	Num agents crossed: 0	Running mean: 0.4774
# Learner:8	Reward total:4	Running mean: 1.969	Num agents crossed: 0	Running mean: 0.4774
# Learner:9	Reward total:2	Running mean: 1.528	Num agents crossed: 0	Running mean: 0.4774
# Max Norms =  ['0.00', '148.77', '189.21', '0.00', '169.48', '0.00', '235.26', '170.52', '201.98', '178.87']
# ........................................................................................................................................................................................................
# Episode 400 complete
# Learner:0	Reward total:9	Running mean: 4.749	Num agents crossed: 2	Running mean: 2.701
# Learner:1	Reward total:0	Running mean: 0.9291	Num agents crossed: 2	Running mean: 2.701
# Learner:2	Reward total:0	Running mean: 0.1376	Num agents crossed: 2	Running mean: 2.701
# Learner:3	Reward total:2	Running mean: 3.793	Num agents crossed: 2	Running mean: 2.701
# Learner:4	Reward total:6	Running mean: 15.75	Num agents crossed: 2	Running mean: 2.701
# Learner:5	Reward total:0	Running mean: 0.7389	Num agents crossed: 2	Running mean: 2.701
# Learner:6	Reward total:78	Running mean: 28.74	Num agents crossed: 2	Running mean: 2.701
# Learner:7	Reward total:11	Running mean: 5.834	Num agents crossed: 2	Running mean: 2.701
# Learner:8	Reward total:26	Running mean: 30.34	Num agents crossed: 2	Running mean: 2.701
# Learner:9	Reward total:5	Running mean: 7.711	Num agents crossed: 2	Running mean: 2.701
# Max Norms =  ['96.21', '0.00', '0.00', '178.48', '118.16', '0.00', '185.95', '97.32', '135.41', '99.60']
# ........................................................................................................................................................................................................
# Episode 600 complete
# Learner:0	Reward total:1	Running mean: 6.055	Num agents crossed: 4	Running mean: 3.924
# Learner:1	Reward total:10	Running mean: 5.961	Num agents crossed: 4	Running mean: 3.924
# Learner:2	Reward total:0	Running mean: 0.1719	Num agents crossed: 4	Running mean: 3.924
# Learner:3	Reward total:51	Running mean: 24.1	Num agents crossed: 4	Running mean: 3.924
# Learner:4	Reward total:0	Running mean: 12.38	Num agents crossed: 4	Running mean: 3.924
# Learner:5	Reward total:15	Running mean: 4.766	Num agents crossed: 4	Running mean: 3.924
# Learner:6	Reward total:30	Running mean: 45.32	Num agents crossed: 4	Running mean: 3.924
# Learner:7	Reward total:15	Running mean: 9.228	Num agents crossed: 4	Running mean: 3.924
# Learner:8	Reward total:39	Running mean: 31.39	Num agents crossed: 4	Running mean: 3.924
# Learner:9	Reward total:18	Running mean: 12.99	Num agents crossed: 4	Running mean: 3.924
# Max Norms =  ['158.57', '190.06', '0.00', '210.89', '0.00', '163.15', '207.98', '70.94', '240.58', '68.49']
# ........................................................................................................................................................................................................
# Episode 800 complete
# Learner:0	Reward total:0	Running mean: 7.661	Num agents crossed: 3	Running mean: 4.471
# Learner:1	Reward total:21	Running mean: 11.02	Num agents crossed: 3	Running mean: 4.471
# Learner:2	Reward total:0	Running mean: 0.2558	Num agents crossed: 3	Running mean: 4.471
# Learner:3	Reward total:67	Running mean: 43.57	Num agents crossed: 3	Running mean: 4.471
# Learner:4	Reward total:16	Running mean: 7.683	Num agents crossed: 3	Running mean: 4.471
# Learner:5	Reward total:1	Running mean: 8.466	Num agents crossed: 3	Running mean: 4.471
# Learner:6	Reward total:45	Running mean: 44.78	Num agents crossed: 3	Running mean: 4.471
# Learner:7	Reward total:0	Running mean: 8.566	Num agents crossed: 3	Running mean: 4.471
# Learner:8	Reward total:14	Running mean: 24.56	Num agents crossed: 3	Running mean: 4.471
# Learner:9	Reward total:22	Running mean: 18.08	Num agents crossed: 3	Running mean: 4.471
# Max Norms =  ['0.00', '170.45', '0.00', '178.05', '87.53', '123.30', '282.88', '0.00', '47.29', '72.52']
# ........................................................................................................................................................................................................
# Episode 1000 complete
# Learner:0	Reward total:19	Running mean: 18.05	Num agents crossed: 4	Running mean: 4.252
# Learner:1	Reward total:19	Running mean: 16.77	Num agents crossed: 4	Running mean: 4.252
# Learner:2	Reward total:0	Running mean: 0.05754	Num agents crossed: 4	Running mean: 4.252
# Learner:3	Reward total:54	Running mean: 46.6	Num agents crossed: 4	Running mean: 4.252
# Learner:4	Reward total:17	Running mean: 5.928	Num agents crossed: 4	Running mean: 4.252
# Learner:5	Reward total:0	Running mean: 4.1	Num agents crossed: 4	Running mean: 4.252
# Learner:6	Reward total:39	Running mean: 46.7	Num agents crossed: 4	Running mean: 4.252
# Learner:7	Reward total:0	Running mean: 11.09	Num agents crossed: 4	Running mean: 4.252
# Learner:8	Reward total:19	Running mean: 19.37	Num agents crossed: 4	Running mean: 4.252
# Learner:9	Reward total:20	Running mean: 19.85	Num agents crossed: 4	Running mean: 4.252
# Max Norms =  ['165.89', '123.32', '0.00', '195.71', '6.88', '0.00', '185.51', '0.00', '82.95', '37.51']
# ........................................................................................................................................................................................................
# Episode 1200 complete
# Learner:0	Reward total:48	Running mean: 32.38	Num agents crossed: 3	Running mean: 4.227
# Learner:1	Reward total:26	Running mean: 21.67	Num agents crossed: 3	Running mean: 4.227
# Learner:2	Reward total:0	Running mean: 0.1585	Num agents crossed: 3	Running mean: 4.227
# Learner:3	Reward total:0	Running mean: 46.08	Num agents crossed: 3	Running mean: 4.227
# Learner:4	Reward total:0	Running mean: 5.928	Num agents crossed: 3	Running mean: 4.227
# Learner:5	Reward total:0	Running mean: 5.13	Num agents crossed: 3	Running mean: 4.227
# Learner:6	Reward total:22	Running mean: 30.07	Num agents crossed: 3	Running mean: 4.227
# Learner:7	Reward total:18	Running mean: 13.68	Num agents crossed: 3	Running mean: 4.227
# Learner:8	Reward total:18	Running mean: 18.92	Num agents crossed: 3	Running mean: 4.227
# Learner:9	Reward total:20	Running mean: 20.08	Num agents crossed: 3	Running mean: 4.227
# Max Norms =  ['139.66', '162.85', '0.00', '0.00', '0.00', '0.00', '279.84', '15.47', '0.94', '18.48']
# ........................................................................................................................................................................................................
# Episode 1400 complete
# Learner:0	Reward total:0	Running mean: 26.32	Num agents crossed: 3	Running mean: 4.067
# Learner:1	Reward total:51	Running mean: 30.75	Num agents crossed: 3	Running mean: 4.067
# Learner:2	Reward total:0	Running mean: 0.359	Num agents crossed: 3	Running mean: 4.067
# Learner:3	Reward total:55	Running mean: 46.62	Num agents crossed: 3	Running mean: 4.067
# Learner:4	Reward total:0	Running mean: 1.054	Num agents crossed: 3	Running mean: 4.067
# Learner:5	Reward total:18	Running mean: 3.144	Num agents crossed: 3	Running mean: 4.067
# Learner:6	Reward total:42	Running mean: 39.95	Num agents crossed: 3	Running mean: 4.067
# Learner:7	Reward total:0	Running mean: 15.74	Num agents crossed: 3	Running mean: 4.067
# Learner:8	Reward total:18	Running mean: 17.52	Num agents crossed: 3	Running mean: 4.067
# Learner:9	Reward total:20	Running mean: 19.91	Num agents crossed: 3	Running mean: 4.067
# Max Norms =  ['0.00', '271.19', '0.00', '157.68', '0.00', '97.44', '187.03', '0.00', '191.89', '2.17']
# ........................................................................................................................................................................................................
# Episode 1600 complete
# Learner:0	Reward total:54	Running mean: 37.58	Num agents crossed: 4	Running mean: 4.365
# Learner:1	Reward total:30	Running mean: 29.5	Num agents crossed: 4	Running mean: 4.365
# Learner:2	Reward total:0	Running mean: 1.117	Num agents crossed: 4	Running mean: 4.365
# Learner:3	Reward total:7	Running mean: 44.85	Num agents crossed: 4	Running mean: 4.365
# Learner:4	Reward total:0	Running mean: 0.4452	Num agents crossed: 4	Running mean: 4.365
# Learner:5	Reward total:0	Running mean: 1.966	Num agents crossed: 4	Running mean: 4.365
# Learner:6	Reward total:48	Running mean: 37.28	Num agents crossed: 4	Running mean: 4.365
# Learner:7	Reward total:18	Running mean: 16.42	Num agents crossed: 4	Running mean: 4.365
# Learner:8	Reward total:18	Running mean: 17.85	Num agents crossed: 4	Running mean: 4.365
# Learner:9	Reward total:20	Running mean: 20.01	Num agents crossed: 4	Running mean: 4.365
# Max Norms =  ['175.88', '145.46', '0.00', '205.53', '0.00', '0.00', '199.64', '19.37', '0.49', '12.89']
# ........................................................................................................................................................................................................
# Episode 1800 complete
# Learner:0	Reward total:41	Running mean: 37.15	Num agents crossed: 5	Running mean: 4.668
# Learner:1	Reward total:44	Running mean: 33.8	Num agents crossed: 5	Running mean: 4.668
# Learner:2	Reward total:4	Running mean: 2.778	Num agents crossed: 5	Running mean: 4.668
# Learner:3	Reward total:31	Running mean: 43.06	Num agents crossed: 5	Running mean: 4.668
# Learner:4	Reward total:0	Running mean: 0.172	Num agents crossed: 5	Running mean: 4.668
# Learner:5	Reward total:0	Running mean: 1.781	Num agents crossed: 5	Running mean: 4.668
# Learner:6	Reward total:44	Running mean: 36.31	Num agents crossed: 5	Running mean: 4.668
# Learner:7	Reward total:18	Running mean: 15.99	Num agents crossed: 5	Running mean: 4.668
# Learner:8	Reward total:18	Running mean: 17.93	Num agents crossed: 5	Running mean: 4.668
# Learner:9	Reward total:20	Running mean: 19.92	Num agents crossed: 5	Running mean: 4.668
# Max Norms =  ['176.74', '179.29', '103.97', '118.13', '0.00', '0.00', '158.07', '41.87', '1.05', '11.89']
# ........................................................................................................................................................................................................
# Episode 2000 complete
# Learner:0	Reward total:43	Running mean: 35.35	Num agents crossed: 5	Running mean: 4.755
# Learner:1	Reward total:36	Running mean: 41.8	Num agents crossed: 5	Running mean: 4.755
# Learner:2	Reward total:20	Running mean: 7.73	Num agents crossed: 5	Running mean: 4.755
# Learner:3	Reward total:31	Running mean: 38.08	Num agents crossed: 5	Running mean: 4.755
# Learner:4	Reward total:0	Running mean: 0.05322	Num agents crossed: 5	Running mean: 4.755
# Learner:5	Reward total:0	Running mean: 1.114	Num agents crossed: 5	Running mean: 4.755
# Learner:6	Reward total:27	Running mean: 32.27	Num agents crossed: 5	Running mean: 4.755
# Learner:7	Reward total:18	Running mean: 16.82	Num agents crossed: 5	Running mean: 4.755
# Learner:8	Reward total:18	Running mean: 17.73	Num agents crossed: 5	Running mean: 4.755
# Learner:9	Reward total:20	Running mean: 19.96	Num agents crossed: 5	Running mean: 4.755
# Max Norms =  ['194.73', '170.34', '164.10', '200.26', '0.00', '0.00', '95.40', '14.61', '1.31', '1.56']
# ........................................................................................................................................................................................................
# Episode 2200 complete
# Learner:0	Reward total:57	Running mean: 44.61	Num agents crossed: 4	Running mean: 4.347
# Learner:1	Reward total:11	Running mean: 32.03	Num agents crossed: 4	Running mean: 4.347
# Learner:2	Reward total:0	Running mean: 4.179	Num agents crossed: 4	Running mean: 4.347
# Learner:3	Reward total:40	Running mean: 35.52	Num agents crossed: 4	Running mean: 4.347
# Learner:4	Reward total:0	Running mean: 0.00713	Num agents crossed: 4	Running mean: 4.347
# Learner:5	Reward total:0	Running mean: 2.658	Num agents crossed: 4	Running mean: 4.347
# Learner:6	Reward total:43	Running mean: 36.93	Num agents crossed: 4	Running mean: 4.347
# Learner:7	Reward total:18	Running mean: 15.89	Num agents crossed: 4	Running mean: 4.347
# Learner:8	Reward total:18	Running mean: 17.84	Num agents crossed: 4	Running mean: 4.347
# Learner:9	Reward total:20	Running mean: 20.09	Num agents crossed: 4	Running mean: 4.347
# Max Norms =  ['154.24', '153.35', '0.00', '216.16', '0.00', '0.00', '178.04', '20.82', '0.77', '1.39']
# ........................................................................................................................................................................................................
# Episode 2400 complete
# Learner:0	Reward total:40	Running mean: 34.53	Num agents crossed: 4	Running mean: 3.804
# Learner:1	Reward total:42	Running mean: 40.21	Num agents crossed: 4	Running mean: 3.804
# Learner:2	Reward total:0	Running mean: 0.5708	Num agents crossed: 4	Running mean: 3.804
# Learner:3	Reward total:31	Running mean: 41.55	Num agents crossed: 4	Running mean: 3.804
# Learner:4	Reward total:0	Running mean: 0.0009553	Num agents crossed: 4	Running mean: 3.804
# Learner:5	Reward total:0	Running mean: 0.9538	Num agents crossed: 4	Running mean: 3.804
# Learner:6	Reward total:50	Running mean: 40.48	Num agents crossed: 4	Running mean: 3.804
# Learner:7	Reward total:17	Running mean: 16.87	Num agents crossed: 4	Running mean: 3.804
# Learner:8	Reward total:18	Running mean: 17.76	Num agents crossed: 4	Running mean: 3.804
# Learner:9	Reward total:20	Running mean: 20.04	Num agents crossed: 4	Running mean: 3.804
# Max Norms =  ['188.60', '175.43', '0.00', '140.67', '0.00', '0.00', '210.07', '18.97', '1.92', '2.83']
# ........................................................................................................................................................................................................
# Episode 2600 complete
# Learner:0	Reward total:0	Running mean: 22.33	Num agents crossed: 3	Running mean: 3.436
# Learner:1	Reward total:38	Running mean: 44.98	Num agents crossed: 3	Running mean: 3.436
# Learner:2	Reward total:0	Running mean: 0.07647	Num agents crossed: 3	Running mean: 3.436
# Learner:3	Reward total:40	Running mean: 44.9	Num agents crossed: 3	Running mean: 3.436
# Learner:4	Reward total:0	Running mean: 0.000128	Num agents crossed: 3	Running mean: 3.436
# Learner:5	Reward total:0	Running mean: 1.309	Num agents crossed: 3	Running mean: 3.436
# Learner:6	Reward total:50	Running mean: 40.41	Num agents crossed: 3	Running mean: 3.436
# Learner:7	Reward total:18	Running mean: 16.51	Num agents crossed: 3	Running mean: 3.436
# Learner:8	Reward total:18	Running mean: 17.76	Num agents crossed: 3	Running mean: 3.436
# Learner:9	Reward total:20	Running mean: 20.0	Num agents crossed: 3	Running mean: 3.436
# Max Norms =  ['0.00', '114.11', '0.00', '104.75', '0.00', '0.00', '128.84', '38.05', '0.22', '14.47']
# ........................................................................................................................................................................................................
# Episode 2800 complete
# Learner:0	Reward total:0	Running mean: 3.392	Num agents crossed: 3	Running mean: 2.692
# Learner:1	Reward total:49	Running mean: 39.26	Num agents crossed: 3	Running mean: 2.692
# Learner:2	Reward total:0	Running mean: 0.01025	Num agents crossed: 3	Running mean: 2.692
# Learner:3	Reward total:55	Running mean: 50.51	Num agents crossed: 3	Running mean: 2.692
# Learner:4	Reward total:0	Running mean: 1.715e-05	Num agents crossed: 3	Running mean: 2.692
# Learner:5	Reward total:11	Running mean: 5.806	Num agents crossed: 3	Running mean: 2.692
# Learner:6	Reward total:53	Running mean: 50.94	Num agents crossed: 3	Running mean: 2.692
# Learner:7	Reward total:7	Running mean: 12.43	Num agents crossed: 3	Running mean: 2.692
# Learner:8	Reward total:18	Running mean: 17.72	Num agents crossed: 3	Running mean: 2.692
# Learner:9	Reward total:20	Running mean: 19.92	Num agents crossed: 3	Running mean: 2.692
# Max Norms =  ['0.00', '190.89', '0.00', '131.19', '0.00', '38.16', '172.20', '45.35', '7.71', '0.73']
# ........................................................................................................................................................................................................
# Episode 3000 complete
# Learner:0	Reward total:0	Running mean: 0.4938	Num agents crossed: 2	Running mean: 2.365
# Learner:1	Reward total:0	Running mean: 23.83	Num agents crossed: 2	Running mean: 2.365
# Learner:2	Reward total:0	Running mean: 0.03847	Num agents crossed: 2	Running mean: 2.365
# Learner:3	Reward total:62	Running mean: 61.72	Num agents crossed: 2	Running mean: 2.365
# Learner:4	Reward total:0	Running mean: 0.03691	Num agents crossed: 2	Running mean: 2.365
# Learner:5	Reward total:0	Running mean: 2.25	Num agents crossed: 2	Running mean: 2.365
# Learner:6	Reward total:69	Running mean: 53.02	Num agents crossed: 2	Running mean: 2.365
# Learner:7	Reward total:18	Running mean: 15.75	Num agents crossed: 2	Running mean: 2.365
# Learner:8	Reward total:18	Running mean: 17.88	Num agents crossed: 2	Running mean: 2.365
# Learner:9	Reward total:20	Running mean: 19.79	Num agents crossed: 2	Running mean: 2.365
# Max Norms =  ['0.00', '0.00', '0.00', '157.55', '0.00', '0.00', '139.93', '14.41', '0.17', '7.47']
#
# Training time: 159.95 min
# Learner agent 0
# Learner agent 1
# Learner agent 2
# Learner agent 3
# Learner agent 4
# Learner agent 5
# Learner agent 6
# Learner agent 7
# Learner agent 8
# Learner agent 9
# ........................................................................................................................................................................................................
# Episode 200 complete
# Learner:0	Reward total:2	Running mean: 0.3095	Num agents crossed: 2	Running mean: 0.1758
# Learner:1	Reward total:1	Running mean: 0.2706	Num agents crossed: 2	Running mean: 0.1758
# Learner:2	Reward total:5	Running mean: 1.817	Num agents crossed: 2	Running mean: 0.1758
# Learner:3	Reward total:0	Running mean: 0.6546	Num agents crossed: 2	Running mean: 0.1758
# Learner:4	Reward total:1	Running mean: 1.625	Num agents crossed: 2	Running mean: 0.1758
# Learner:5	Reward total:4	Running mean: 0.3527	Num agents crossed: 2	Running mean: 0.1758
# Learner:6	Reward total:12	Running mean: 1.389	Num agents crossed: 2	Running mean: 0.1758
# Learner:7	Reward total:0	Running mean: 0.5955	Num agents crossed: 2	Running mean: 0.1758
# Learner:8	Reward total:2	Running mean: 1.252	Num agents crossed: 2	Running mean: 0.1758
# Learner:9	Reward total:2	Running mean: 0.8548	Num agents crossed: 2	Running mean: 0.1758
# Max Norms =  ['157.22', '148.27', '172.63', '0.00', '251.87', '173.91', '200.66', '0.00', '223.26', '172.96']
# ........................................................................................................................................................................................................
# Episode 400 complete
# Learner:0	Reward total:5	Running mean: 0.8957	Num agents crossed: 5	Running mean: 1.435
# Learner:1	Reward total:0	Running mean: 0.5373	Num agents crossed: 5	Running mean: 1.435
# Learner:2	Reward total:51	Running mean: 37.58	Num agents crossed: 5	Running mean: 1.435
# Learner:3	Reward total:3	Running mean: 3.452	Num agents crossed: 5	Running mean: 1.435
# Learner:4	Reward total:7	Running mean: 10.37	Num agents crossed: 5	Running mean: 1.435
# Learner:5	Reward total:2	Running mean: 1.296	Num agents crossed: 5	Running mean: 1.435
# Learner:6	Reward total:0	Running mean: 1.605	Num agents crossed: 5	Running mean: 1.435
# Learner:7	Reward total:20	Running mean: 2.381	Num agents crossed: 5	Running mean: 1.435
# Learner:8	Reward total:0	Running mean: 3.125	Num agents crossed: 5	Running mean: 1.435
# Learner:9	Reward total:5	Running mean: 13.82	Num agents crossed: 5	Running mean: 1.435
# Max Norms =  ['176.70', '0.00', '189.82', '196.36', '183.63', '128.84', '0.00', '89.06', '0.00', '121.38']
# ........................................................................................................................................................................................................
# Episode 600 complete
# Learner:0	Reward total:22	Running mean: 5.247	Num agents crossed: 4	Running mean: 3.34
# Learner:1	Reward total:12	Running mean: 1.63	Num agents crossed: 4	Running mean: 3.34
# Learner:2	Reward total:40	Running mean: 46.02	Num agents crossed: 4	Running mean: 3.34
# Learner:3	Reward total:18	Running mean: 9.991	Num agents crossed: 4	Running mean: 3.34
# Learner:4	Reward total:0	Running mean: 11.19	Num agents crossed: 4	Running mean: 3.34
# Learner:5	Reward total:0	Running mean: 10.96	Num agents crossed: 4	Running mean: 3.34
# Learner:6	Reward total:52	Running mean: 14.18	Num agents crossed: 4	Running mean: 3.34
# Learner:7	Reward total:18	Running mean: 11.12	Num agents crossed: 4	Running mean: 3.34
# Learner:8	Reward total:0	Running mean: 1.755	Num agents crossed: 4	Running mean: 3.34
# Learner:9	Reward total:20	Running mean: 16.65	Num agents crossed: 4	Running mean: 3.34
# Max Norms =  ['152.94', '106.90', '155.01', '8.08', '0.00', '0.00', '167.08', '39.68', '0.00', '68.30']
# ........................................................................................................................................................................................................
# Episode 800 complete
# Learner:0	Reward total:0	Running mean: 8.489	Num agents crossed: 3	Running mean: 3.343
# Learner:1	Reward total:6	Running mean: 5.839	Num agents crossed: 3	Running mean: 3.343
# Learner:2	Reward total:53	Running mean: 50.66	Num agents crossed: 3	Running mean: 3.343
# Learner:3	Reward total:18	Running mean: 11.74	Num agents crossed: 3	Running mean: 3.343
# Learner:4	Reward total:0	Running mean: 5.773	Num agents crossed: 3	Running mean: 3.343
# Learner:5	Reward total:0	Running mean: 3.429	Num agents crossed: 3	Running mean: 3.343
# Learner:6	Reward total:48	Running mean: 34.93	Num agents crossed: 3	Running mean: 3.343
# Learner:7	Reward total:17	Running mean: 13.74	Num agents crossed: 3	Running mean: 3.343
# Learner:8	Reward total:0	Running mean: 5.992	Num agents crossed: 3	Running mean: 3.343
# Learner:9	Reward total:20	Running mean: 17.28	Num agents crossed: 3	Running mean: 3.343
# Max Norms =  ['0.00', '222.17', '182.99', '10.24', '0.00', '0.00', '164.34', '14.27', '0.00', '33.33']
# ........................................................................................................................................................................................................
# Episode 1000 complete
# Learner:0	Reward total:29	Running mean: 13.97	Num agents crossed: 4	Running mean: 2.953
# Learner:1	Reward total:0	Running mean: 6.802	Num agents crossed: 4	Running mean: 2.953
# Learner:2	Reward total:14	Running mean: 48.15	Num agents crossed: 4	Running mean: 2.953
# Learner:3	Reward total:12	Running mean: 8.289	Num agents crossed: 4	Running mean: 2.953
# Learner:4	Reward total:0	Running mean: 1.933	Num agents crossed: 4	Running mean: 2.953
# Learner:5	Reward total:40	Running mean: 3.684	Num agents crossed: 4	Running mean: 2.953
# Learner:6	Reward total:46	Running mean: 39.15	Num agents crossed: 4	Running mean: 2.953
# Learner:7	Reward total:0	Running mean: 11.86	Num agents crossed: 4	Running mean: 2.953
# Learner:8	Reward total:13	Running mean: 13.54	Num agents crossed: 4	Running mean: 2.953
# Learner:9	Reward total:20	Running mean: 17.77	Num agents crossed: 4	Running mean: 2.953
# Max Norms =  ['148.48', '0.00', '208.72', '23.77', '0.00', '107.81', '210.41', '0.00', '79.83', '33.28']
# ........................................................................................................................................................................................................
# Episode 1200 complete
# Learner:0	Reward total:31	Running mean: 29.92	Num agents crossed: 4	Running mean: 3.324
# Learner:1	Reward total:33	Running mean: 10.26	Num agents crossed: 4	Running mean: 3.324
# Learner:2	Reward total:41	Running mean: 45.62	Num agents crossed: 4	Running mean: 3.324
# Learner:3	Reward total:17	Running mean: 4.621	Num agents crossed: 4	Running mean: 3.324
# Learner:4	Reward total:4	Running mean: 0.9297	Num agents crossed: 4	Running mean: 3.324
# Learner:5	Reward total:0	Running mean: 2.187	Num agents crossed: 4	Running mean: 3.324
# Learner:6	Reward total:45	Running mean: 41.11	Num agents crossed: 4	Running mean: 3.324
# Learner:7	Reward total:8	Running mean: 11.84	Num agents crossed: 4	Running mean: 3.324
# Learner:8	Reward total:0	Running mean: 16.44	Num agents crossed: 4	Running mean: 3.324
# Learner:9	Reward total:18	Running mean: 18.78	Num agents crossed: 4	Running mean: 3.324
# Max Norms =  ['122.37', '132.01', '255.09', '1.13', '44.11', '0.00', '169.21', '23.07', '0.00', '40.09']
# ........................................................................................................................................................................................................
# Episode 1400 complete
# Learner:0	Reward total:43	Running mean: 33.87	Num agents crossed: 4	Running mean: 3.621
# Learner:1	Reward total:0	Running mean: 5.787	Num agents crossed: 4	Running mean: 3.621
# Learner:2	Reward total:41	Running mean: 41.15	Num agents crossed: 4	Running mean: 3.621
# Learner:3	Reward total:3	Running mean: 7.669	Num agents crossed: 4	Running mean: 3.621
# Learner:4	Reward total:0	Running mean: 2.267	Num agents crossed: 4	Running mean: 3.621
# Learner:5	Reward total:0	Running mean: 1.445	Num agents crossed: 4	Running mean: 3.621
# Learner:6	Reward total:48	Running mean: 52.57	Num agents crossed: 4	Running mean: 3.621
# Learner:7	Reward total:18	Running mean: 13.46	Num agents crossed: 4	Running mean: 3.621
# Learner:8	Reward total:18	Running mean: 13.9	Num agents crossed: 4	Running mean: 3.621
# Learner:9	Reward total:20	Running mean: 19.8	Num agents crossed: 4	Running mean: 3.621
# Max Norms =  ['176.34', '0.00', '253.93', '120.53', '0.00', '0.00', '141.49', '18.72', '44.71', '40.25']
# ........................................................................................................................................................................................................
# Episode 1600 complete
# Learner:0	Reward total:42	Running mean: 30.41	Num agents crossed: 4	Running mean: 4.272
# Learner:1	Reward total:0	Running mean: 10.23	Num agents crossed: 4	Running mean: 4.272
# Learner:2	Reward total:38	Running mean: 33.06	Num agents crossed: 4	Running mean: 4.272
# Learner:3	Reward total:21	Running mean: 20.3	Num agents crossed: 4	Running mean: 4.272
# Learner:4	Reward total:0	Running mean: 4.174	Num agents crossed: 4	Running mean: 4.272
# Learner:5	Reward total:0	Running mean: 2.44	Num agents crossed: 4	Running mean: 4.272
# Learner:6	Reward total:56	Running mean: 51.58	Num agents crossed: 4	Running mean: 4.272
# Learner:7	Reward total:18	Running mean: 11.55	Num agents crossed: 4	Running mean: 4.272
# Learner:8	Reward total:17	Running mean: 15.5	Num agents crossed: 4	Running mean: 4.272
# Learner:9	Reward total:21	Running mean: 21.75	Num agents crossed: 4	Running mean: 4.272
# Max Norms =  ['152.70', '0.00', '131.91', '143.09', '0.00', '0.00', '214.04', '12.20', '15.62', '30.13']
# ........................................................................................................................................................................................................
# Episode 1800 complete
# Learner:0	Reward total:43	Running mean: 21.25	Num agents crossed: 5	Running mean: 3.808
# Learner:1	Reward total:25	Running mean: 9.582	Num agents crossed: 5	Running mean: 3.808
# Learner:2	Reward total:31	Running mean: 36.51	Num agents crossed: 5	Running mean: 3.808
# Learner:3	Reward total:15	Running mean: 26.4	Num agents crossed: 5	Running mean: 3.808
# Learner:4	Reward total:0	Running mean: 2.756	Num agents crossed: 5	Running mean: 3.808
# Learner:5	Reward total:27	Running mean: 2.158	Num agents crossed: 5	Running mean: 3.808
# Learner:6	Reward total:0	Running mean: 50.97	Num agents crossed: 5	Running mean: 3.808
# Learner:7	Reward total:18	Running mean: 13.46	Num agents crossed: 5	Running mean: 3.808
# Learner:8	Reward total:17	Running mean: 15.77	Num agents crossed: 5	Running mean: 3.808
# Learner:9	Reward total:21	Running mean: 21.4	Num agents crossed: 5	Running mean: 3.808
# Max Norms =  ['185.32', '120.66', '76.11', '155.02', '0.00', '202.62', '0.00', '5.87', '8.56', '12.59']
# ........................................................................................................................................................................................................
# Episode 2000 complete
# Learner:0	Reward total:25	Running mean: 13.36	Num agents crossed: 5	Running mean: 3.87
# Learner:1	Reward total:32	Running mean: 10.46	Num agents crossed: 5	Running mean: 3.87
# Learner:2	Reward total:29	Running mean: 37.4	Num agents crossed: 5	Running mean: 3.87
# Learner:3	Reward total:32	Running mean: 30.29	Num agents crossed: 5	Running mean: 3.87
# Learner:4	Reward total:0	Running mean: 3.566	Num agents crossed: 5	Running mean: 3.87
# Learner:5	Reward total:18	Running mean: 2.584	Num agents crossed: 5	Running mean: 3.87
# Learner:6	Reward total:40	Running mean: 50.94	Num agents crossed: 5	Running mean: 3.87
# Learner:7	Reward total:18	Running mean: 11.4	Num agents crossed: 5	Running mean: 3.87
# Learner:8	Reward total:0	Running mean: 16.41	Num agents crossed: 5	Running mean: 3.87
# Learner:9	Reward total:20	Running mean: 21.77	Num agents crossed: 5	Running mean: 3.87
# Max Norms =  ['169.97', '224.60', '231.64', '157.32', '0.00', '419.47', '136.51', '16.97', '0.00', '32.99']
# ........................................................................................................................................................................................................
# Episode 2200 complete
# Learner:0	Reward total:12	Running mean: 26.75	Num agents crossed: 5	Running mean: 4.164
# Learner:1	Reward total:0	Running mean: 4.329	Num agents crossed: 5	Running mean: 4.164
# Learner:2	Reward total:47	Running mean: 31.45	Num agents crossed: 5	Running mean: 4.164
# Learner:3	Reward total:11	Running mean: 36.56	Num agents crossed: 5	Running mean: 4.164
# Learner:4	Reward total:31	Running mean: 8.456	Num agents crossed: 5	Running mean: 4.164
# Learner:5	Reward total:18	Running mean: 5.074	Num agents crossed: 5	Running mean: 4.164
# Learner:6	Reward total:53	Running mean: 41.92	Num agents crossed: 5	Running mean: 4.164
# Learner:7	Reward total:0	Running mean: 6.664	Num agents crossed: 5	Running mean: 4.164
# Learner:8	Reward total:18	Running mean: 17.04	Num agents crossed: 5	Running mean: 4.164
# Learner:9	Reward total:20	Running mean: 24.14	Num agents crossed: 5	Running mean: 4.164
# Max Norms =  ['151.68', '0.00', '223.23', '258.86', '240.07', '62.60', '199.45', '0.00', '7.59', '1.68']
# ........................................................................................................................................................................................................
# Episode 2400 complete
# Learner:0	Reward total:0	Running mean: 4.908	Num agents crossed: 2	Running mean: 3.347
# Learner:1	Reward total:0	Running mean: 4.298	Num agents crossed: 2	Running mean: 3.347
# Learner:2	Reward total:60	Running mean: 43.7	Num agents crossed: 2	Running mean: 3.347
# Learner:3	Reward total:71	Running mean: 46.12	Num agents crossed: 2	Running mean: 3.347
# Learner:4	Reward total:4	Running mean: 4.178	Num agents crossed: 2	Running mean: 3.347
# Learner:5	Reward total:1	Running mean: 4.159	Num agents crossed: 2	Running mean: 3.347
# Learner:6	Reward total:0	Running mean: 49.12	Num agents crossed: 2	Running mean: 3.347
# Learner:7	Reward total:0	Running mean: 10.37	Num agents crossed: 2	Running mean: 3.347
# Learner:8	Reward total:18	Running mean: 15.71	Num agents crossed: 2	Running mean: 3.347
# Learner:9	Reward total:31	Running mean: 23.04	Num agents crossed: 2	Running mean: 3.347
# Max Norms =  ['0.00', '0.00', '123.36', '131.90', '130.20', '161.73', '0.00', '0.00', '164.54', '17.77']
# ........................................................................................................................................................................................................
# Episode 2600 complete
# Learner:0	Reward total:0	Running mean: 0.9965	Num agents crossed: 3	Running mean: 3.359
# Learner:1	Reward total:0	Running mean: 5.969	Num agents crossed: 3	Running mean: 3.359
# Learner:2	Reward total:47	Running mean: 47.65	Num agents crossed: 3	Running mean: 3.359
# Learner:3	Reward total:44	Running mean: 42.43	Num agents crossed: 3	Running mean: 3.359
# Learner:4	Reward total:0	Running mean: 8.737	Num agents crossed: 3	Running mean: 3.359
# Learner:5	Reward total:15	Running mean: 3.271	Num agents crossed: 3	Running mean: 3.359
# Learner:6	Reward total:62	Running mean: 47.2	Num agents crossed: 3	Running mean: 3.359
# Learner:7	Reward total:0	Running mean: 8.231	Num agents crossed: 3	Running mean: 3.359
# Learner:8	Reward total:18	Running mean: 16.38	Num agents crossed: 3	Running mean: 3.359
# Learner:9	Reward total:22	Running mean: 24.24	Num agents crossed: 3	Running mean: 3.359
# Max Norms =  ['0.00', '0.00', '147.95', '103.25', '0.00', '17.28', '114.38', '0.00', '25.08', '69.83']
# ........................................................................................................................................................................................................
# Episode 2800 complete
# Learner:0	Reward total:0	Running mean: 2.09	Num agents crossed: 3	Running mean: 3.296
# Learner:1	Reward total:0	Running mean: 4.145	Num agents crossed: 3	Running mean: 3.296
# Learner:2	Reward total:35	Running mean: 33.07	Num agents crossed: 3	Running mean: 3.296
# Learner:3	Reward total:46	Running mean: 49.34	Num agents crossed: 3	Running mean: 3.296
# Learner:4	Reward total:10	Running mean: 4.4	Num agents crossed: 3	Running mean: 3.296
# Learner:5	Reward total:0	Running mean: 3.279	Num agents crossed: 3	Running mean: 3.296
# Learner:6	Reward total:72	Running mean: 55.42	Num agents crossed: 3	Running mean: 3.296
# Learner:7	Reward total:0	Running mean: 14.27	Num agents crossed: 3	Running mean: 3.296
# Learner:8	Reward total:18	Running mean: 16.95	Num agents crossed: 3	Running mean: 3.296
# Learner:9	Reward total:27	Running mean: 21.95	Num agents crossed: 3	Running mean: 3.296
# Max Norms =  ['0.00', '0.00', '162.62', '120.23', '139.15', '0.00', '162.67', '0.00', '16.32', '35.39']
# ........................................................................................................................................................................................................
# Episode 3000 complete
# Learner:0	Reward total:0	Running mean: 8.16	Num agents crossed: 5	Running mean: 4.385
# Learner:1	Reward total:0	Running mean: 2.288	Num agents crossed: 5	Running mean: 4.385
# Learner:2	Reward total:38	Running mean: 34.74	Num agents crossed: 5	Running mean: 4.385
# Learner:3	Reward total:37	Running mean: 43.09	Num agents crossed: 5	Running mean: 4.385
# Learner:4	Reward total:10	Running mean: 3.906	Num agents crossed: 5	Running mean: 4.385
# Learner:5	Reward total:17	Running mean: 11.58	Num agents crossed: 5	Running mean: 4.385
# Learner:6	Reward total:58	Running mean: 55.77	Num agents crossed: 5	Running mean: 4.385
# Learner:7	Reward total:17	Running mean: 15.78	Num agents crossed: 5	Running mean: 4.385
# Learner:8	Reward total:18	Running mean: 17.61	Num agents crossed: 5	Running mean: 4.385
# Learner:9	Reward total:21	Running mean: 22.28	Num agents crossed: 5	Running mean: 4.385
# Max Norms =  ['0.00', '0.00', '227.75', '287.49', '203.51', '87.27', '132.93', '24.37', '7.51', '0.80']
#
# Training time: 160.17 min

# %% [markdown]
# ## Graphs
#
# This cell block plots the learning curves of:
#
# * Running rewards (apples gathered)
# * Num of agents who have crossed over to the 2nd food pile
#
# for teams trained under various parameter sets of (starting temp, game steps).

# %%
game = 'Crossing'

"""
############# EXPERIMENT = PACIFIST #######################

dir_names = [
############# 1T10L/Baseline , map = food_d37 #############
            "results/1T-10L/baseline/food_d37/pacifist/t1.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.0_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.25_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.25_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.5_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.5_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t1.5_rp-1.0_1200gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t2.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t2.0_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t2.0_rp-1.0_1200gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t4.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t4.0_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t4.0_rp-1.0_1200gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t8.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t8.0_rp-1.0_600gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t8.0_rp-1.0_1200gs/",
            
############# 1T10L/Baseline , map = food_d37_river_w1_d25 #############            
            "results/1T-10L/baseline/food_d37_river_w1_d25/pacifist/t1.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37_river_w1_d25/pacifist/t1.25_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37_river_w1_d25/pacifist/t2.0_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37_river_w1_d25/pacifist/t4.0_rp-1.0_300gs/",            
]

num_learners = 10
num_tribes = 1

# Cultural parameter search
culture = 'pacifist'

"""


############# EXPERIMENT = PACIFIST ###################################
############# 1T10L/Baseline , map = food_d37 #############
dir_names = [
            "results/1T-10L/baseline/food_d37/pacifist/t0.4_rp-1.0_300gs/",
            "results/1T-10L/baseline/food_d37/pacifist/t0.8_rp-1.0_300gs/",
]

num_learners = 10
num_tribes = 1

# Cultural parameter search
culture = 'pacifist'

agents = []
for i in range(num_learners):
    print("Load AI agent {}".format(i))
    agents.append(Policy(7, 8, i))

# agents.append(Rdn_Policy())

# Establish tribal association
tribes = []
tribes.append(Tribe(name='Vikings',color='blue', culture=culture, \
                    agents=[agents[0], agents[1], agents[2], agents[3], agents[4], \
                           agents[5], agents[6], agents[7], agents[8], agents[9]]))

# 10 agents in 1 tribes
agent_colors = [agent.color for agent in agents]
agent_tribes = [agent.tribe for agent in agents]

for dir_name in dir_names:
    print (dir_name)
    data = [[] for i in range(num_learners)]

    # Load rewards
    for i in range(num_learners):
        data_file = dir_name+'MA{}_{}.p'.format(i, game)
        with open(data_file, 'rb') as f:
            data[i] = pickle.load(f)
    
    crossed_file = dir_name+'Crossed.p'.format(i, game)
    with open(crossed_file, 'rb') as f:
            crossed = pickle.load(f)
            
    total = [sum(x) for x in zip(*data)]

    for i in range(num_learners):
        print('Final Running Reward - MA{} Ind Reward: {:.3f}'.format(i, data[i][-1]))
    
    print('Final Running Reward - All Agents: {:.3f}'.format(total[-1]))

    plt.figure(figsize=(10, 7))
    plt.plot(total, label='Total Rewards', color='green')
    for i in range(num_learners):
        plt.plot(data[i], label='MA{}_CNN Indv'.format(i), color=agent_colors[i])

    plt.title('Agent Rewards versus Episodes')
    plt.xlabel('Episodes')
    plt.ylabel('Average Rewards')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(10, 7))
    plt.plot(crossed, label='Agents Crossed', color='green')

    plt.title('Agents Gathering in 2nd Food Pile')
    plt.xlabel('Episodes')
    plt.ylabel('Num Agents')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Load AI agent 0
# Load AI agent 1
# Load AI agent 2
# Load AI agent 3
# Load AI agent 4
# Load AI agent 5
# Load AI agent 6
# Load AI agent 7
# Load AI agent 8
# Load AI agent 9
# results/1T-10L/baseline/food_d37/pacifist/t0.4_rp-1.0_300gs/
# Final Running Reward - MA0 Ind Reward: 8.160
# Final Running Reward - MA1 Ind Reward: 2.288
# Final Running Reward - MA2 Ind Reward: 34.736
# Final Running Reward - MA3 Ind Reward: 43.093
# Final Running Reward - MA4 Ind Reward: 3.906
# Final Running Reward - MA5 Ind Reward: 11.583
# Final Running Reward - MA6 Ind Reward: 55.768
# Final Running Reward - MA7 Ind Reward: 15.777
# Final Running Reward - MA8 Ind Reward: 17.613
# Final Running Reward - MA9 Ind Reward: 22.283
# Final Running Reward - All Agents: 215.208
# results/1T-10L/baseline/food_d37/pacifist/t0.8_rp-1.0_300gs/
# Final Running Reward - MA0 Ind Reward: 0.494
# Final Running Reward - MA1 Ind Reward: 23.835
# Final Running Reward - MA2 Ind Reward: 0.038
# Final Running Reward - MA3 Ind Reward: 61.719
# Final Running Reward - MA4 Ind Reward: 0.037
# Final Running Reward - MA5 Ind Reward: 2.250
# Final Running Reward - MA6 Ind Reward: 53.024
# Final Running Reward - MA7 Ind Reward: 15.749
# Final Running Reward - MA8 Ind Reward: 17.881
# Final Running Reward - MA9 Ind Reward: 19.795
# Final Running Reward - All Agents: 194.821
